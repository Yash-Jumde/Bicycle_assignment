# %% [markdown]
# # Transaction Data Processing
#
# This notebook processes transaction data with optimized memory management and handles data quality issues.

# %%
import pandas as pd
import numpy as np
import os
import sys
from glob import glob
import gc
from datetime import datetime
import warnings
import psutil  # For memory monitoring
from tqdm import tqdm  # For progress bars (install with pip install tqdm if needed)
import time

# %%
def get_memory_usage():
    """Return the current memory usage in MB"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 * 1024)

def log_memory(message):
    """Log memory usage with a custom message"""
    print(f"{message}: {get_memory_usage():.2f} MB")

# %% [markdown]
# ## 1. Data Cleaning Functions
#
# Define functions for cleaning and feature engineering before we use them

# %%
def clean_chunk(df):
    """Clean a chunk of transaction data with optimized operations"""
    # Make a copy only if needed (can improve performance but may cause SettingWithCopyWarning)
    df = df.copy()
    
    # Handle string columns efficiently by processing only non-null values
    str_cols = ['merchant_name', 'merchant_category', 'currency', 'location_country', 'location_city', 'device_type', 'status']
    for col in str_cols:
        if col in df.columns:
            if df[col].dtype == 'string' or df[col].dtype == 'object':
                # Only process non-null values to save time
                mask = df[col].notna()
                if mask.any():
                    df.loc[mask, col] = df.loc[mask, col].str.strip().str.lower()
            
            # Handle categorical columns properly before filling with 'unknown'
            if pd.api.types.is_categorical_dtype(df[col]):
                # Add 'unknown' to the category list if it's not already there
                if 'unknown' not in df[col].cat.categories:
                    df[col] = df[col].cat.add_categories(['unknown'])
            
            # Fill missing values
            df[col] = df[col].fillna('unknown')
    
    # Handle missing numeric values more efficiently
    if 'amount' in df.columns:
        df['missing_amount'] = df['amount'].isna()
        df['amount'] = df['amount'].fillna(0)
    
    # Handle missing boolean values
    if 'is_online' in df.columns:
        df['is_online'] = df['is_online'].fillna(False)
    
    # Handle outliers in amount using vectorized operations
    if 'amount' in df.columns:
        # Use robust statistics to avoid influence of extreme outliers
        q1 = df['amount'].quantile(0.25)
        q3 = df['amount'].quantile(0.75)
        iqr = q3 - q1
        upper_limit = q3 + 1.5 * iqr
        df['is_amount_outlier'] = df['amount'] > upper_limit
    
    # Drop duplicates efficiently using subset
    df.drop_duplicates(subset='transaction_id', keep='first', inplace=True)
    
    return df

# %% [markdown]
# ## 2. Feature Engineering Functions

# %%
def add_derived_features(df):
    """Add derived features to the dataframe with minimal memory impact"""
    # Ensure timestamp is a datetime object
    if 'timestamp' in df.columns:
        # Make sure timestamp is datetime type
        if not pd.api.types.is_datetime64_any_dtype(df['timestamp']):
            df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
        
        # Extract time-based features efficiently
        df['day_of_week'] = df['timestamp'].dt.dayofweek
        df['is_weekend'] = df['day_of_week'].isin([5, 6])
        df['hour'] = df['timestamp'].dt.hour
        
        # Time period categorization
        conditions = [
            (df['hour'] < 6),
            (df['hour'] >= 6) & (df['hour'] < 12),
            (df['hour'] >= 12) & (df['hour'] < 18),
            (df['hour'] >= 18)
        ]
        choices = ['night', 'morning', 'afternoon', 'evening']
        df['time_period'] = np.select(conditions, choices, default='unknown')
        
        # Calculate days since transaction efficiently
        current_date = pd.Timestamp(datetime.now().date())
        df['days_since_transaction'] = (current_date - df['timestamp'].dt.floor('D')).dt.days
    
    # Flag potential anomalies using vectorized operations
    if 'amount' in df.columns and 'is_online' in df.columns:
        df['high_value_online'] = (df['amount'] > 1000) & df['is_online']
    
    return df

# %% [markdown]
# ## 3. Memory-Efficient Processing Function

# %%
def process_transactions(file_list, chunksize=100000, output_dir="processed_chunks", max_files=None):
    """
    Process transaction files in chunks with improved memory management and proper deduplication
    """

    # Import required modules
    import os
    import gc
    import pandas as pd
    import numpy as np
    import time
    from tqdm import tqdm
    
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    # Limit number of files if specified
    if max_files is not None and max_files < len(file_list):
        print(f"Limiting to {max_files} out of {len(file_list)} files")
        file_list = file_list[:max_files]
    
    # Track processing statistics
    total_rows_processed = 0
    total_chunks_processed = 0
    start_time = time.time()
    output_files = []
    
    # IMPROVED APPROACH: Create a single set of transaction IDs that we'll update as we process each file
    # This way we'll only keep track of transactions we've already processed
    seen_transaction_ids = set()
    
    # Process each file and save to parquet
    print("\n--- Processing and saving files ---")
    
    for i, file_path in enumerate(file_list):
        file_start_time = time.time()
        print(f"\nProcessing file {i+1}/{len(file_list)}: {os.path.basename(os.path.dirname(file_path))}")
        log_memory(f"Memory before processing file {i+1}")
        
        try:
            # Get file size for progress reporting
            file_size = os.path.getsize(file_path) / (1024 * 1024)  # Size in MB
            print(f"File size: {file_size:.2f} MB")
            
            # Calculate expected chunks
            with open(file_path, 'r') as f:
                approx_rows = sum(1 for _ in f) - 1  # Subtract header
            print(f"Approximate rows: {approx_rows:,}")
            expected_chunks = approx_rows // chunksize + (1 if approx_rows % chunksize else 0)
            
            # Create output file path for this file
            output_file = os.path.join(output_dir, f"processed_file_{i+1}.parquet")
            
            # Process current file in chunks
            chunk_reader = pd.read_csv(
                file_path, 
                dtype=dtypes,
                parse_dates=['timestamp'],
                chunksize=chunksize
            )
            
            # Initialize a buffer for this file's processed chunks
            processed_chunks = []
            file_rows_processed = 0
            
            # Process each chunk
            for chunk_idx, chunk in enumerate(tqdm(chunk_reader, total=expected_chunks, desc=f"Processing file {i+1}")):
                # Convert timestamp if needed
                if not pd.api.types.is_datetime64_any_dtype(chunk['timestamp']):
                    chunk['timestamp'] = pd.to_datetime(chunk['timestamp'], errors='coerce')
                
                # Clean data
                chunk = clean_chunk(chunk)
                
                # IMPROVED: Filter out only transaction IDs we've already seen
                # Get the current chunk's transaction IDs
                current_ids = set(chunk['transaction_id'])
                
                # Find which transaction IDs in this chunk are duplicates (already seen)
                duplicate_ids = current_ids.intersection(seen_transaction_ids)
                
                # Remove duplicates if any found
                if duplicate_ids:
                    chunk = chunk[~chunk['transaction_id'].isin(duplicate_ids)]
                
                # Add the non-duplicate transaction IDs to our seen set
                seen_transaction_ids.update(current_ids - duplicate_ids)
                
                # Skip further processing if chunk is empty after deduplication
                if len(chunk) == 0:
                    continue
                
                # Add derived features
                chunk = add_derived_features(chunk)
                
                # Add to processed chunks
                processed_chunks.append(chunk)
                file_rows_processed += len(chunk)
                
                # Update stats
                total_rows_processed += len(chunk)
                total_chunks_processed += 1
                
                # Check memory usage, if too high, save intermediate results
                current_mem = get_memory_usage()
                if current_mem > 2000 or (chunk_idx > 0 and chunk_idx % 5 == 0):  # Save every 5 chunks or if memory high
                    # Combine processed chunks and save
                    if processed_chunks:
                        combined_df = pd.concat(processed_chunks, ignore_index=True)
                        # If first chunk set, save to new file, otherwise append
                        if not os.path.exists(output_file):
                            combined_df.to_parquet(output_file)
                        else:
                            existing_df = pd.read_parquet(output_file)
                            pd.concat([existing_df, combined_df], ignore_index=True).to_parquet(output_file)
                            del existing_df
                        
                        # Clear memory
                        del combined_df
                        processed_chunks = []
                        gc.collect()
            
            # Save any remaining chunks
            if processed_chunks:
                combined_df = pd.concat(processed_chunks, ignore_index=True)
                # If we've already written to the file, append
                if os.path.exists(output_file):
                    existing_df = pd.read_parquet(output_file)
                    pd.concat([existing_df, combined_df], ignore_index=True).to_parquet(output_file)
                    del existing_df
                else:
                    combined_df.to_parquet(output_file)
                
                # Clear memory
                del combined_df
                processed_chunks = []
                gc.collect()
            
            # Add output file to list if it exists and has data
            if os.path.exists(output_file):
                file_size = os.path.getsize(output_file) / (1024 * 1024)  # Size in MB
                print(f"Created output file: {output_file} ({file_size:.2f} MB)")
                output_files.append(output_file)
                print(f"Rows processed in this file: {file_rows_processed:,}")
            
            file_time = time.time() - file_start_time
            print(f"File {i+1} processed in {file_time:.2f} seconds")
            
            # Periodic garbage collection
            gc.collect()
            
        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            import traceback
            traceback.print_exc()
    
    # Report overall statistics
    total_time = time.time() - start_time
    rows_per_second = total_rows_processed / total_time if total_time > 0 else 0
    print(f"\nProcessing complete!")
    print(f"Total rows processed: {total_rows_processed:,}")
    print(f"Total chunks processed: {total_chunks_processed:,}")
    print(f"Total output files: {len(output_files)}")
    print(f"Total processing time: {total_time:.2f} seconds")
    print(f"Processing speed: {rows_per_second:.2f} rows per second")
    
    # Return the list of output files
    return output_files

# %% [markdown]
# ## 4. Configure Data Loading

# %%
# Define optimized dtypes
dtypes = {
    'transaction_id': 'string',
    'user_id': 'string',
    'merchant_id': 'string',
    'merchant_name': 'string',
    'merchant_category': 'category',
    'amount': 'float32',
    'currency': 'category',
    'location_country': 'category',
    'location_city': 'category',
    'is_online': 'bool',
    'device_type': 'category',
    'status': 'category'
}

# Find all transaction files
base_dir = 'transaction_data'
all_csv_files = glob(os.path.join(base_dir, '**', 'transactions.csv'), recursive=True)
print(f"Found {len(all_csv_files)} transaction files")
# Out:
# Found 31 transaction files

# %% [markdown]
# ## 5. Process the Data

# %%
SAMPLE_FRACTION = None # Process 5% of the data to build a representative sample
MAX_FILES = None  # Limit to first N files for initial analysis
CHUNK_SIZE = 100000  # Adjust based on available RAM

# %%
print("\n=== STARTING DATA PROCESSING ===")
log_memory("Initial memory usage")

# Comment out the sampling parameters for full dataset processing once your code is working
output_files = process_transactions(
    all_csv_files, 
    chunksize=CHUNK_SIZE,
    output_dir="processed_chunks",
    max_files=MAX_FILES  # Remove this for full processing
)

log_memory("Memory usage after data loading")

# Load the processed data for analysis
if output_files:
    print(f"Successfully processed {len(output_files)} files")
    # Load the first file to get a sample for initial exploration
    sample_df = pd.read_parquet(output_files[0])
    print(f"Sample DataFrame shape: {sample_df.shape}")
    print(f"Sample DataFrame memory usage: {sample_df.memory_usage(deep=True).sum() / (1024**2):.2f} MB")
else:
    print("No output files were generated")
# Out:
# === STARTING DATA PROCESSING ===
# Initial memory usage: 119.88 MB
#
# --- Processing and saving files ---
#
# Processing file 1/31: 2025-04-07
# Memory before processing file 1: 119.88 MB
# File size: 245.77 MB
# Approximate rows: 1,708,500
# Processing file 1:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:   6%|▌         | 1/18 [00:00<00:06,  2.57it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  11%|█         | 2/18 [00:00<00:06,  2.50it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  17%|█▋        | 3/18 [00:01<00:06,  2.49it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  22%|██▏       | 4/18 [00:01<00:05,  2.46it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  28%|██▊       | 5/18 [00:02<00:05,  2.45it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  33%|███▎      | 6/18 [00:03<00:08,  1.39it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  39%|███▉      | 7/18 [00:03<00:06,  1.58it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  44%|████▍     | 8/18 [00:04<00:05,  1.72it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  50%|█████     | 9/18 [00:04<00:04,  1.87it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  56%|█████▌    | 10/18 [00:05<00:04,  1.98it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  61%|██████    | 11/18 [00:07<00:07,  1.05s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  67%|██████▋   | 12/18 [00:07<00:05,  1.17it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  72%|███████▏  | 13/18 [00:08<00:03,  1.36it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  78%|███████▊  | 14/18 [00:08<00:02,  1.54it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  83%|████████▎ | 15/18 [00:09<00:01,  1.69it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  89%|████████▉ | 16/18 [00:12<00:02,  1.36s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1:  94%|█████████▍| 17/18 [00:12<00:01,  1.09s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 1: 100%|██████████| 18/18 [00:12<00:00,  1.40it/s]
# Created output file: processed_chunks\processed_file_1.parquet (81.97 MB)
# Rows processed in this file: 1,708,500
# File 1 processed in 16.94 seconds
#
# Processing file 2/31: 2025-04-08
# Memory before processing file 2: 1112.18 MB
# File size: 245.77 MB
# Approximate rows: 1,708,500
# Processing file 2:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:   6%|▌         | 1/18 [00:00<00:07,  2.19it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  11%|█         | 2/18 [00:00<00:07,  2.18it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  17%|█▋        | 3/18 [00:01<00:06,  2.17it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  22%|██▏       | 4/18 [00:01<00:06,  2.18it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  28%|██▊       | 5/18 [00:02<00:05,  2.19it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  33%|███▎      | 6/18 [00:03<00:09,  1.31it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  39%|███▉      | 7/18 [00:04<00:07,  1.48it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  44%|████▍     | 8/18 [00:04<00:06,  1.64it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  50%|█████     | 9/18 [00:05<00:05,  1.72it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  56%|█████▌    | 10/18 [00:05<00:04,  1.82it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  61%|██████    | 11/18 [00:07<00:07,  1.11s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  67%|██████▋   | 12/18 [00:08<00:05,  1.08it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  72%|███████▏  | 13/18 [00:08<00:03,  1.26it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  78%|███████▊  | 14/18 [00:09<00:02,  1.42it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  83%|████████▎ | 15/18 [00:09<00:01,  1.56it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  89%|████████▉ | 16/18 [00:13<00:02,  1.45s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2:  94%|█████████▍| 17/18 [00:13<00:01,  1.17s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 2: 100%|██████████| 18/18 [00:13<00:00,  1.30it/s]
# Created output file: processed_chunks\processed_file_2.parquet (81.97 MB)
# Rows processed in this file: 1,708,500
# File 2 processed in 18.02 seconds
#
# Processing file 3/31: 2025-04-09
# Memory before processing file 3: 1328.94 MB
# File size: 245.77 MB
# Approximate rows: 1,708,500
# Processing file 3:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:   6%|▌         | 1/18 [00:00<00:09,  1.86it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  11%|█         | 2/18 [00:01<00:08,  1.86it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  17%|█▋        | 3/18 [00:01<00:07,  1.91it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  22%|██▏       | 4/18 [00:02<00:07,  1.88it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  28%|██▊       | 5/18 [00:02<00:06,  1.90it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  33%|███▎      | 6/18 [00:04<00:10,  1.17it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  39%|███▉      | 7/18 [00:04<00:08,  1.29it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  44%|████▍     | 8/18 [00:05<00:07,  1.30it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  50%|█████     | 9/18 [00:06<00:07,  1.27it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  56%|█████▌    | 10/18 [00:07<00:06,  1.28it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  61%|██████    | 11/18 [00:10<00:11,  1.65s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  67%|██████▋   | 12/18 [00:11<00:08,  1.40s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  72%|███████▏  | 13/18 [00:12<00:06,  1.23s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  78%|███████▊  | 14/18 [00:13<00:04,  1.11s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  83%|████████▎ | 15/18 [00:14<00:03,  1.03s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  89%|████████▉ | 16/18 [00:19<00:04,  2.23s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3:  94%|█████████▍| 17/18 [00:20<00:01,  1.85s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 3: 100%|██████████| 18/18 [00:20<00:00,  1.12s/it]
# Created output file: processed_chunks\processed_file_3.parquet (81.97 MB)
# Rows processed in this file: 1,708,500
# File 3 processed in 25.93 seconds
#
# Processing file 4/31: 2025-04-10
# Memory before processing file 4: 1796.72 MB
# File size: 245.76 MB
# Approximate rows: 1,708,500
# Processing file 4:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:   6%|▌         | 1/18 [00:00<00:10,  1.68it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  11%|█         | 2/18 [00:01<00:09,  1.63it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  17%|█▋        | 3/18 [00:01<00:09,  1.59it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  22%|██▏       | 4/18 [00:02<00:08,  1.62it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  28%|██▊       | 5/18 [00:03<00:08,  1.62it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  33%|███▎      | 6/18 [00:04<00:12,  1.00s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  39%|███▉      | 7/18 [00:05<00:09,  1.12it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  44%|████▍     | 8/18 [00:06<00:08,  1.23it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  50%|█████     | 9/18 [00:06<00:06,  1.31it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  56%|█████▌    | 10/18 [00:07<00:05,  1.39it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  61%|██████    | 11/18 [00:10<00:09,  1.29s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  67%|██████▋   | 12/18 [00:10<00:06,  1.09s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  72%|███████▏  | 13/18 [00:11<00:04,  1.06it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  78%|███████▊  | 14/18 [00:11<00:03,  1.18it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  83%|████████▎ | 15/18 [00:12<00:02,  1.29it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  89%|████████▉ | 16/18 [00:15<00:03,  1.60s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4:  94%|█████████▍| 17/18 [00:16<00:01,  1.31s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 4: 100%|██████████| 18/18 [00:16<00:00,  1.08it/s]
# Created output file: processed_chunks\processed_file_4.parquet (81.96 MB)
# Rows processed in this file: 1,708,500
# File 4 processed in 20.96 seconds
#
# Processing file 5/31: 2025-04-11
# Memory before processing file 5: 1929.74 MB
# File size: 245.76 MB
# Approximate rows: 1,708,500
# Processing file 5:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:   6%|▌         | 1/18 [00:00<00:11,  1.51it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  11%|█         | 2/18 [00:01<00:10,  1.57it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  17%|█▋        | 3/18 [00:02<00:15,  1.00s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  22%|██▏       | 4/18 [00:03<00:12,  1.16it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  28%|██▊       | 5/18 [00:05<00:15,  1.17s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  33%|███▎      | 6/18 [00:07<00:17,  1.43s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  39%|███▉      | 7/18 [00:07<00:12,  1.18s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  44%|████▍     | 8/18 [00:08<00:10,  1.02s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  50%|█████     | 9/18 [00:09<00:08,  1.09it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  56%|█████▌    | 10/18 [00:09<00:06,  1.20it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  61%|██████    | 11/18 [00:12<00:09,  1.41s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  67%|██████▋   | 12/18 [00:15<00:11,  1.88s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  72%|███████▏  | 13/18 [00:18<00:11,  2.25s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  78%|███████▊  | 14/18 [00:19<00:07,  1.77s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  83%|████████▎ | 15/18 [00:22<00:06,  2.30s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  89%|████████▉ | 16/18 [00:26<00:05,  2.74s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5:  94%|█████████▍| 17/18 [00:30<00:03,  3.11s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 5: 100%|██████████| 18/18 [00:33<00:00,  1.87s/it]
# Created output file: processed_chunks\processed_file_5.parquet (81.97 MB)
# Rows processed in this file: 1,708,500
# File 5 processed in 34.76 seconds
#
# Processing file 6/31: 2025-04-12
# Memory before processing file 6: 2105.76 MB
# File size: 245.75 MB
# Approximate rows: 1,708,500
# Processing file 6:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:   6%|▌         | 1/18 [00:01<00:18,  1.07s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  11%|█         | 2/18 [00:02<00:19,  1.19s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  17%|█▋        | 3/18 [00:03<00:19,  1.32s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  22%|██▏       | 4/18 [00:05<00:20,  1.45s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  28%|██▊       | 5/18 [00:07<00:20,  1.61s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  33%|███▎      | 6/18 [00:09<00:20,  1.73s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  39%|███▉      | 7/18 [00:11<00:20,  1.89s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  44%|████▍     | 8/18 [00:13<00:20,  2.04s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  50%|█████     | 9/18 [00:16<00:19,  2.18s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  56%|█████▌    | 10/18 [00:19<00:18,  2.34s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  61%|██████    | 11/18 [00:22<00:17,  2.57s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  67%|██████▋   | 12/18 [00:25<00:16,  2.80s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  72%|███████▏  | 13/18 [00:28<00:15,  3.00s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  78%|███████▊  | 14/18 [00:32<00:12,  3.20s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  83%|████████▎ | 15/18 [00:36<00:10,  3.35s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  89%|████████▉ | 16/18 [00:40<00:07,  3.63s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6:  94%|█████████▍| 17/18 [00:44<00:03,  3.77s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 6: 100%|██████████| 18/18 [00:47<00:00,  2.67s/it]
# Created output file: processed_chunks\processed_file_6.parquet (81.97 MB)
# Rows processed in this file: 1,708,500
# File 6 processed in 49.19 seconds
#
# Processing file 7/31: 2025-04-13
# Memory before processing file 7: 2623.96 MB
# File size: 245.78 MB
# Approximate rows: 1,708,500
# Processing file 7:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:   6%|▌         | 1/18 [00:01<00:22,  1.32s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  11%|█         | 2/18 [00:02<00:23,  1.46s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  17%|█▋        | 3/18 [00:04<00:23,  1.59s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  22%|██▏       | 4/18 [00:06<00:24,  1.77s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  28%|██▊       | 5/18 [00:08<00:24,  1.89s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  33%|███▎      | 6/18 [00:11<00:25,  2.09s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  39%|███▉      | 7/18 [00:13<00:24,  2.26s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  44%|████▍     | 8/18 [00:17<00:26,  2.65s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  50%|█████     | 9/18 [00:21<00:28,  3.20s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  56%|█████▌    | 10/18 [00:26<00:29,  3.63s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  61%|██████    | 11/18 [00:31<00:27,  3.98s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  67%|██████▋   | 12/18 [00:36<00:26,  4.34s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  72%|███████▏  | 13/18 [00:41<00:23,  4.63s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  78%|███████▊  | 14/18 [00:46<00:18,  4.71s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  83%|████████▎ | 15/18 [00:50<00:13,  4.45s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  89%|████████▉ | 16/18 [00:54<00:08,  4.27s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7:  94%|█████████▍| 17/18 [00:58<00:04,  4.24s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 7: 100%|██████████| 18/18 [01:01<00:00,  3.44s/it]
# Created output file: processed_chunks\processed_file_7.parquet (81.97 MB)
# Rows processed in this file: 1,708,500
# File 7 processed in 63.13 seconds
#
# Processing file 8/31: 2025-04-14
# Memory before processing file 8: 2770.77 MB
# File size: 245.77 MB
# Approximate rows: 1,708,500
# Processing file 8:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:   6%|▌         | 1/18 [00:01<00:33,  1.97s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  11%|█         | 2/18 [00:04<00:34,  2.18s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  17%|█▋        | 3/18 [00:06<00:34,  2.33s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  22%|██▏       | 4/18 [00:09<00:35,  2.50s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  28%|██▊       | 5/18 [00:12<00:34,  2.66s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  33%|███▎      | 6/18 [00:15<00:33,  2.83s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  39%|███▉      | 7/18 [00:19<00:33,  3.06s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  44%|████▍     | 8/18 [00:22<00:32,  3.25s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  50%|█████     | 9/18 [00:26<00:31,  3.48s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  56%|█████▌    | 10/18 [00:30<00:29,  3.69s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 8:  61%|██████    | 11/18 [00:34<00:25,  3.60s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
# ...
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  56%|█████▌    | 10/18 [01:02<00:53,  6.67s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  61%|██████    | 11/18 [01:09<00:48,  6.93s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  67%|██████▋   | 12/18 [01:17<00:42,  7.13s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  72%|███████▏  | 13/18 [01:25<00:36,  7.37s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  78%|███████▊  | 14/18 [01:33<00:31,  7.77s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  83%|████████▎ | 15/18 [01:47<00:28,  9.35s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  89%|████████▉ | 16/18 [02:00<00:21, 10.63s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29:  94%|█████████▍| 17/18 [02:11<00:10, 10.84s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 29: 100%|██████████| 18/18 [02:20<00:00,  7.79s/it]
# Created output file: processed_chunks\processed_file_29.parquet (81.96 MB)
# Rows processed in this file: 1,708,500
# File 29 processed in 141.20 seconds
#
# Processing file 30/31: 2025-05-06
# Memory before processing file 30: 7487.72 MB
# File size: 245.77 MB
# Approximate rows: 1,708,500
# Processing file 30:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:   6%|▌         | 1/18 [00:08<02:17,  8.07s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  11%|█         | 2/18 [00:16<02:13,  8.36s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  17%|█▋        | 3/18 [00:25<02:07,  8.48s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  22%|██▏       | 4/18 [00:34<02:00,  8.62s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  28%|██▊       | 5/18 [00:42<01:52,  8.67s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  33%|███▎      | 6/18 [00:52<01:47,  8.93s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  39%|███▉      | 7/18 [01:01<01:40,  9.17s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  44%|████▍     | 8/18 [01:13<01:39,  9.98s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  50%|█████     | 9/18 [01:22<01:26,  9.58s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  56%|█████▌    | 10/18 [01:30<01:12,  9.02s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  61%|██████    | 11/18 [01:37<01:00,  8.61s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  67%|██████▋   | 12/18 [01:45<00:50,  8.33s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  72%|███████▏  | 13/18 [01:53<00:41,  8.32s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  78%|███████▊  | 14/18 [02:04<00:36,  9.18s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  83%|████████▎ | 15/18 [02:18<00:31, 10.54s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  89%|████████▉ | 16/18 [02:31<00:22, 11.37s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30:  94%|█████████▍| 17/18 [02:41<00:10, 10.72s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 30: 100%|██████████| 18/18 [02:47<00:00,  9.31s/it]
# Created output file: processed_chunks\processed_file_30.parquet (81.98 MB)
# Rows processed in this file: 1,708,500
# File 30 processed in 168.75 seconds
#
# Processing file 31/31: 2025-05-07
# Memory before processing file 31: 7710.64 MB
# File size: 245.76 MB
# Approximate rows: 1,708,500
# Processing file 31:   0%|          | 0/18 [00:00<?, ?it/s]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:   6%|▌         | 1/18 [00:05<01:36,  5.65s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  11%|█         | 2/18 [00:11<01:32,  5.80s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  17%|█▋        | 3/18 [00:17<01:28,  5.92s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  22%|██▏       | 4/18 [00:23<01:24,  6.05s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  28%|██▊       | 5/18 [00:30<01:23,  6.42s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  33%|███▎      | 6/18 [00:42<01:38,  8.22s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  39%|███▉      | 7/18 [00:52<01:36,  8.77s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  44%|████▍     | 8/18 [01:02<01:30,  9.08s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  50%|█████     | 9/18 [01:10<01:18,  8.73s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  56%|█████▌    | 10/18 [01:19<01:11,  8.94s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  61%|██████    | 11/18 [01:30<01:06,  9.54s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  67%|██████▋   | 12/18 [01:43<01:03, 10.61s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  72%|███████▏  | 13/18 [01:56<00:56, 11.32s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  78%|███████▊  | 14/18 [02:09<00:47, 11.93s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  83%|████████▎ | 15/18 [02:22<00:36, 12.15s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  89%|████████▉ | 16/18 [02:35<00:24, 12.42s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31:  94%|█████████▍| 17/18 [02:49<00:12, 12.72s/it]C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10444\244038399.py:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(df[col]):
# Processing file 31: 100%|██████████| 18/18 [02:57<00:00,  9.89s/it]
# Created output file: processed_chunks\processed_file_31.parquet (81.98 MB)
# Rows processed in this file: 1,708,500
# File 31 processed in 178.93 seconds
#
# Processing complete!
# Total rows processed: 52,963,500
# Total chunks processed: 558
# Total output files: 31
# Total processing time: 2695.49 seconds
# Processing speed: 19648.93 rows per second
# Memory usage after data loading: 1721.60 MB
# Successfully processed 31 files
# Sample DataFrame shape: (1708500, 21)
# Sample DataFrame memory usage: 658.27 MB

# %% [markdown]
# ## Data Overview
